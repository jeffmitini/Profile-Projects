# %% [markdown]
# # Data Wrangling using Pandas

# %% [markdown]
# Data wrangling is an iterative process of preparing and enhancing data that will be used for analysis. This is also called data munging. This process is repeated until the result, which is data that clean and analysis ready is achieved (Azeroual, 2020).
#
# The project below demonstrates data wrangling practices as a way of preparing data to be used to answer the question: what has been the trend in cybercrime for the past 5 years in Kansas City?

# %% [markdown]
# # Datasets

# %% [markdown]
# The dataset is the Kansas City crime information for 5 years, 2017 to 2021, obtained from https://data.kcmo.org/Crime/KCPD-Crime-Data-2020/vsgj-uufz. The 5 datasets were downloaded individually, and the steps that follow show how they were cleaned and combined

# %% [markdown]
# # Importing Libraries and 2020 dataset

# %%
#Import Pandas Library
import pandas as pd

# %%
#Reading csv files
df20 = pd.read_csv("crime20.csv")

# %%
df20.describe()
# Out:
#            Zip Code           Age
# count  8.459900e+04  73157.000000
# mean   9.439290e+04     37.807797
# std    4.407061e+06     13.978460
# min    5.301000e+03     18.000000
# 25%    6.411300e+04     27.000000
# 50%    6.412700e+04     35.000000
# 75%    6.413200e+04     47.000000
# max    6.413030e+08     99.000000

# %%
print(df20)
# Out:
#         Report_No Reported_Date Reported Time   From_Date From Time  \
# 0      KC20067792    10/04/2020         11:04  10/03/2020     18:00
# 1      KC20017500    03/08/2020         19:24  03/08/2020     19:00
# 2      KC20009823    02/07/2020         18:30  02/07/2020     18:01
# 3      KC20011191    02/13/2020         12:15  02/13/2020     12:15
# 4      KC20014727    02/27/2020         08:30  01/12/2020     16:35
# ...           ...           ...           ...         ...       ...
# 96215  KC20078294    11/14/2020         10:07  11/14/2020     09:06
# 96216  KC20081488    11/27/2020         23:29  11/27/2020     23:39
# 96217  KC20082700    12/03/2020         08:34  12/03/2020     07:30
# 96218  KC20074368    10/29/2020         20:12  10/29/2020     06:45
# 96219  KC20087950    12/25/2020         11:35  12/24/2020     21:00
#
#           To_Date To Time                                        Offense IBRS  \
# 0             NaN     NaN                               Stealing – Other  23H
# 1      03/08/2020   19:00                            Stealing – Shoplift  90J
# 2             NaN     NaN                         Robbery (Armed Street)  120
# 3      02/13/2020   12:15                            Stealing – Shoplift  23C
# 4             NaN     NaN                    Miscellaneous Investigation  NaN
# ...           ...     ...                                            ...  ...
# 96215         NaN     NaN  Harassment / Intimidation - Domestic Violence  13C
# 96216         NaN     NaN         Domestic Violence Assault (Aggravated)  13A
# 96217         NaN     NaN                                    Stolen Auto  240
# 96218  10/29/2020   18:40               Stealing from Building/Residence  23D
# 96219  12/25/2020   09:00    Stealing from Auto (Auto Part or Accessory)  23G
#
#                                   Description  ... Zip Code Rep_Dist Area  \
# 0                           All Other Larceny  ...  64131.0      NaN  CPD
# 1                   Trespass of Real Property  ...  64133.0   PJ3601  EPD
# 2                                     Robbery  ...  64134.0   PJ6554  SPD
# 3                                 Shoplifting  ...  64133.0   PJ3601  EPD
# 4                                         NaN  ...  64128.0   PJ3281  EPD
# ...                                       ...  ...      ...      ...  ...
# 96215                            Intimidation  ...  64137.0   PJ6874  SPD
# 96216                      Aggravated Assault  ...      NaN      NaN  EPD
# 96217                     Motor Vehicle Theft  ...  64117.0   PC1131  SCP
# 96218                     Theft From Building  ...  64132.0   PJ4990  MPD
# 96219  Theft of Vehicle Parts and Accessories  ...  64113.0   PJ2838  EPD
#
#        DVFlag  Involvement Race  Sex   Age Firearm Used Flag  \
# 0           N          SUS    B    M   NaN             False
# 1           N          VIC  NaN  NaN   NaN             False
# 2           N          SUS    B    M   NaN              True
# 3           N  ARR CHA SUS    B    M  37.0             False
# 4           N      CMP VIC    W    F  38.0             False
# ...       ...          ...  ...  ...   ...               ...
# 96215       N          VIC    B    M  42.0             False
# 96216       N          VIC    B    F  19.0              True
# 96217       N  ARR CHA SUS    W    F  27.0             False
# 96218       N          VIC    W    F  37.0             False
# 96219       N          VIC    W    M  60.0             False
#
#                                                 Location
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 96215  10400  CHESTNUT AVE\nKANSAS CITY 64137\n(38.93...
# 96216  8500  INDEPENDENCE AVE\nKANSAS CITY\n(39.10386...
# 96217  4400  N BRIGHTON AVE\nKANSAS CITY 64117\n(39.1...
# 96218  2300  E MEYER BLVD\nKANSAS CITY 64132\n(39.007...
# 96219                                                NaN
#
# [96220 rows x 23 columns]

# %% [markdown]
# # Importing the rest of the datasets into Python

# %%
df21 = pd.read_csv("crime21.csv", low_memory=False)
df19 = pd.read_csv("crime19.csv", low_memory=False)
df18 = pd.read_csv("crime18.csv")
df17 = pd.read_csv("crime17.csv")

# %%
print(df17, df18, df19, df20, df21)
# Out:
#         Report_No Reported_Date Reported_Time   From_Date From_Time  \
# 0       170096892    11/14/2017         15:39  11/14/2017     15:06
# 1       170021297    03/25/2017         18:28  03/25/2017     18:26
# 2       170069219    08/07/2017         14:46  08/07/2017     14:40
# 3       170107018    12/23/2017         20:10  12/23/2017     20:10
# 4       170077301    09/04/2017         22:21  08/30/2017     18:00
# ...           ...           ...           ...         ...       ...
# 132134  170065892    07/26/2017         09:09  07/26/2017     09:09
# 132135  170102647    12/06/2017         22:59  12/06/2017     22:59
# 132136  170084282    09/28/2017         12:44  09/27/2017     23:00
# 132137  170094257    11/04/2017         12:06  11/04/2017     12:06
# 132138  170085448    10/02/2017         20:12  10/02/2017     19:30
#
#            To_Date To_Time  Offense IBRS           Description  ...  Rep_Dist  \
# 0              NaN     NaN      630  23C  Stealing Shoplifting  ...       NaN
# 1              NaN     NaN     1850  35B  Possession of Drug E  ...    PJ2738
# 2              NaN     NaN     2655  90J           Trespassing  ...    PP0365
# 3              NaN     NaN      802  13B  Non Agg Assault Dome  ...    PJ7135
# 4       09/04/2017   22:21      302  120         Armed Robbery  ...    PJ3077
# ...            ...     ...      ...  ...                   ...  ...       ...
# 132134         NaN     NaN      401  13A  Aggravated Assault (  ...    PJ4382
# 132135  12/06/2017   22:59      801  13B  Non Aggravated Assau  ...    PJ3485
# 132136  09/28/2017   09:00      702  240            Auto Theft  ...    PJ5117
# 132137         NaN     NaN      630  23C  Stealing Shoplifting  ...    PC0323
# 132138         NaN     NaN      302  120         Armed Robbery  ...    PJ2479
#
#        Area DVFlag  Invl_No Involvement Race  Sex   Age Firearm Used Flag  \
# 0       NaN      U        2         VIC  NaN  NaN   NaN                 N
# 1       EPD      U        2         VIC  NaN  NaN   NaN                 N
# 2       NPD      U        1         VIC  NaN  NaN   NaN                 N
# 3       SPD      Y        1         VIC    B    F  18.0                 N
# 4       EPD      U        1         SUS    B    M  30.0                 N
# ...     ...    ...      ...         ...  ...  ...   ...               ...
# 132134  MPD      U        1         SUS    U    U   NaN                 Y
# 132135  CPD      U        1         VIC    W    F  27.0                 N
# 132136  MPD      U        1         VIC    B    F  22.0                 N
# 132137  NPD      U        1         VIC  NaN  NaN   NaN                 N
# 132138  CPD      N        1         SUS    B    M   NaN                 Y
#
#                                                  Location
# 0                            200 W 6TH\nKANSAS CITY 64105
# 1                         8900 E US\nHW KANSAS CITY 64129
# 2                     7100 NW BARRY RD\nKANSAS CITY 64151
# 3                        7000 E 113\nTE KANSAS CITY 64134
# 4                  39 ST and NORTON AV\nKANSAS CITY 64130
# ...                                                   ...
# 132134  5300 JACKSON AV\nKANSAS CITY 64130\n(39.029484...
# 132135  4400 WORNALL RD\nKANSAS CITY 64111\n(39.046134...
# 132136  6600 WALROND AV\nKANSAS CITY 64132\n(39.007549...
# 132137  8500 N MADISON AV\nKANSAS CITY 64155\n(39.2483...
# 132138  31 ST and OLIVE ST\nKANSAS CITY 64109\n(39.069...
#
# [132139 rows x 24 columns]         Report_No Reported_Date Reported_Time   From_Date From_Time  \
# 0       180009419    02/07/2018         16:35  02/07/2018     11:00
# 1       180035722    05/20/2018         03:32  05/20/2018     03:32
# 2       180037437    05/19/2018         00:21  05/19/2018       NaN
# 3       180039506    05/26/2018         01:00  05/26/2018     01:00
# 4       180036600    05/16/2018         09:13  05/16/2018     01:00
# ...           ...           ...           ...         ...       ...
# 128933  180098606    12/23/2018         21:45  12/23/2018     21:45
# 128934  180099275    12/27/2018         10:52  12/27/2018     10:52
# 128935  180099745    12/29/2018         09:45  12/24/2018     18:00
# 128936  180098929    12/25/2018         21:33  12/25/2018     21:33
# 128937  180098906    12/25/2018         17:39  12/25/2018     17:00
#
#            To_Date To_Time  Offense IBRS           Description  ... Rep_Dist  \
# 0       02/07/2018   15:30      640  23F    Stealing From Auto  ...   PJ1316
# 1              NaN     NaN     1352  280  Stolen Property OFFE  ...   PJ2803
# 2              NaN     NaN     2100  90D  Driving Under Influe  ...   PJ2226
# 3              NaN     NaN     2655  90J           Trespassing  ...   PJ1084
# 4       05/16/2018   09:13      702  240            Auto Theft  ...   PJ1077
# ...            ...     ...      ...  ...                   ...  ...      ...
# 128933         NaN     NaN      101  09A  HOMICIDE/Non Neglige  ...   PJ1904
# 128934         NaN     NaN      630  23C  Stealing Shoplifting  ...   PJ6174
# 128935  12/29/2018   08:00      501  220  Burglary - Residence  ...   PJ7370
# 128936         NaN     NaN      802  13B  Non Agg Assault Dome  ...   PJ5994
# 128937         NaN     NaN      630  23C  Stealing Shoplifting  ...   PJ3637
#
#        Area DVFlag  Invl_No Involvement Race  Sex   Age Firearm Used Flag  \
# 0       CPD      U        1         VIC  NaN  NaN   NaN                 N
# 1       EPD      U        1         ARR    B    M   NaN                 N
# 2       EPD      U        1         ARR    B    F  46.0                 N
# 3       CPD      U        1         VIC    W    M  31.0                 N
# 4       CPD      U        1         SUS    U    U   NaN                 N
# ...     ...    ...      ...         ...  ...  ...   ...               ...
# 128933  EPD      U        1         VIC    B    M   NaN                 Y
# 128934  MPD      U        1         SUS    B    M   NaN                 N
# 128935  SPD      U        1         VIC    W    M  72.0                 N
# 128936  MPD      Y        1         VIC    B    F  33.0                 N
# 128937  CPD      U        1         SUS    B    M  40.0                 N
#
#                                                  Location
# 0                          E FOREST AV\nKANSAS CITY 64127
# 1            35 ST and SOUTH BENTON AV\nKANSAS CITY 64130
# 2                    2600 VAN\nBRUNT BL KANSAS CITY 64128
# 3       1200 MAIN ST\nKANSAS CITY 64106\n(39.09961, -9...
# 4       1200 JEFFERSON ST\nKANSAS CITY 64105\n(39.1001...
# ...                                                   ...
# 128933            23 ST and TOPPING AV\nKANSAS CITY 99999
# 128934  8600 WARD PK S\nKANSAS CITY 64114\n(38.971462,...
# 128935                      0 E 127\nTE KANSAS CITY 64145
# 128936  8200 WAYNE AV\nKANSAS CITY 64132\n(38.978977, ...
# 128937  4500 TROOST AV\nKANSAS CITY 64110\n(39.044992,...
#
# [128938 rows x 24 columns]          Report_No Reported_Date Reported_Time  From_Date From_Time  \
# 0       KC19044451     6/14/2019         16:34  6/14/2019     16:30
# 1       KC19052276     7/12/2019         22:11  7/13/2019      2:28
# 2       KC19071090     9/17/2019         13:26  9/17/2019     13:15
# 3       KC19073018     9/24/2019          7:32  9/24/2019      7:20
# 4       KC19076088     10/4/2019         13:59  10/4/2019     13:50
# ...            ...           ...           ...        ...       ...
# 103767   190021100     3/22/2019         22:00  3/22/2019     22:00
# 103768   190021380     3/24/2019          8:26  3/23/2019     17:30
# 103769   190020958     3/22/2019         12:08  3/22/2019     12:08
# 103770   190021533     3/25/2019          0:13  3/25/2019      0:05
# 103771   190020848     3/22/2019          1:07  3/22/2019      1:07
#
#           To_Date To_Time                        Offense IBRS     Description  \
# 0       6/14/2019   16:30            Stealing – Shoplift  23C     Shoplifting
# 1             NaN     NaN  City/Municipal Warrant Arrest  NaN             NaN
# 2             NaN     NaN            Stealing – Shoplift  23C     Shoplifting
# 3             NaN     NaN               Abuse of a Child  13B  Simple Assault
# 4             NaN     NaN          Recovered Stolen Auto  NaN             NaN
# ...           ...     ...                            ...  ...             ...
# 103767        NaN     NaN           Stealing from Buildi  23D             NaN
# 103768  3/24/2019    7:45                Property Damage  290             NaN
# 103769        NaN     NaN           Aggravated Assault (  13A             NaN
# 103770  3/25/2019    0:20           Aggravated Assault (  13A             NaN
# 103771        NaN     NaN           Resisting an Officer  90Z             NaN
#
#         ... Zip Code Rep_Dist Area  DVFlag  Involvement Race  Sex   Age  \
# 0       ...  64114.0      NaN  MPD       N          VIC  NaN  NaN   NaN
# 1       ...      NaN      NaN  NaN       N  ARR CHA SUS    W    F  30.0
# 2       ...  64132.0      NaN  MPD       N          VIC  NaN  NaN   NaN
# 3       ...  64138.0   PJ6509  SPD       Y          SUS    B    M  39.0
# 4       ...      NaN      NaN  CPD       N          VIC  NaN  NaN   NaN
# ...     ...      ...      ...  ...     ...          ...  ...  ...   ...
# 103767  ...  64110.0   PJ4431  MPD       U          SUS    B    M  18.0
# 103768  ...  64113.0   PJ4326  MPD       U          VIC    W    M  55.0
# 103769  ...  64134.0   PJ7135  SPD       N          VIC    B    M  61.0
# 103770  ...  64127.0   PJ0703  EPD       U          VIC    B    F  25.0
# 103771  ...  64124.0   PJ0722  EPD       U          ARR    B    M  27.0
#
#        Firearm Used Flag                                           Location
# 0                  False                                                NaN
# 1                  False                                                NaN
# 2                  False                                                NaN
# 3                  False                                                NaN
# 4                  False                                                NaN
# ...                  ...                                                ...
# 103767             False                                                NaN
# 103768             False  30 E 55 ST\nKANSAS CITY 64113\n(39.027621, -94...
# 103769              True  7003 E 113 ST\nKANSAS CITY 64134\n(38.918492, ...
# 103770              True                                                NaN
# 103771             False  4815 INDEPENDENCE AV\nKANSAS CITY 64124\n(39.1...
#
# [103772 rows x 23 columns]         Report_No Reported_Date Reported Time   From_Date From Time  \
# 0      KC20067792    10/04/2020         11:04  10/03/2020     18:00
# 1      KC20017500    03/08/2020         19:24  03/08/2020     19:00
# 2      KC20009823    02/07/2020         18:30  02/07/2020     18:01
# 3      KC20011191    02/13/2020         12:15  02/13/2020     12:15
# 4      KC20014727    02/27/2020         08:30  01/12/2020     16:35
# ...           ...           ...           ...         ...       ...
# 96215  KC20078294    11/14/2020         10:07  11/14/2020     09:06
# 96216  KC20081488    11/27/2020         23:29  11/27/2020     23:39
# 96217  KC20082700    12/03/2020         08:34  12/03/2020     07:30
# 96218  KC20074368    10/29/2020         20:12  10/29/2020     06:45
# 96219  KC20087950    12/25/2020         11:35  12/24/2020     21:00
#
#           To_Date To Time                                        Offense IBRS  \
# 0             NaN     NaN                               Stealing – Other  23H
# 1      03/08/2020   19:00                            Stealing – Shoplift  90J
# 2             NaN     NaN                         Robbery (Armed Street)  120
# 3      02/13/2020   12:15                            Stealing – Shoplift  23C
# 4             NaN     NaN                    Miscellaneous Investigation  NaN
# ...           ...     ...                                            ...  ...
# 96215         NaN     NaN  Harassment / Intimidation - Domestic Violence  13C
# 96216         NaN     NaN         Domestic Violence Assault (Aggravated)  13A
# 96217         NaN     NaN                                    Stolen Auto  240
# 96218  10/29/2020   18:40               Stealing from Building/Residence  23D
# 96219  12/25/2020   09:00    Stealing from Auto (Auto Part or Accessory)  23G
#
#                                   Description  ... Zip Code Rep_Dist Area  \
# 0                           All Other Larceny  ...  64131.0      NaN  CPD
# 1                   Trespass of Real Property  ...  64133.0   PJ3601  EPD
# 2                                     Robbery  ...  64134.0   PJ6554  SPD
# 3                                 Shoplifting  ...  64133.0   PJ3601  EPD
# 4                                         NaN  ...  64128.0   PJ3281  EPD
# ...                                       ...  ...      ...      ...  ...
# 96215                            Intimidation  ...  64137.0   PJ6874  SPD
# 96216                      Aggravated Assault  ...      NaN      NaN  EPD
# 96217                     Motor Vehicle Theft  ...  64117.0   PC1131  SCP
# 96218                     Theft From Building  ...  64132.0   PJ4990  MPD
# 96219  Theft of Vehicle Parts and Accessories  ...  64113.0   PJ2838  EPD
#
#        DVFlag  Involvement Race  Sex   Age Firearm Used Flag  \
# 0           N          SUS    B    M   NaN             False
# 1           N          VIC  NaN  NaN   NaN             False
# 2           N          SUS    B    M   NaN              True
# 3           N  ARR CHA SUS    B    M  37.0             False
# 4           N      CMP VIC    W    F  38.0             False
# ...       ...          ...  ...  ...   ...               ...
# 96215       N          VIC    B    M  42.0             False
# 96216       N          VIC    B    F  19.0              True
# 96217       N  ARR CHA SUS    W    F  27.0             False
# 96218       N          VIC    W    F  37.0             False
# 96219       N          VIC    W    M  60.0             False
#
#                                                 Location
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 96215  10400  CHESTNUT AVE\nKANSAS CITY 64137\n(38.93...
# 96216  8500  INDEPENDENCE AVE\nKANSAS CITY\n(39.10386...
# 96217  4400  N BRIGHTON AVE\nKANSAS CITY 64117\n(39.1...
# 96218  2300  E MEYER BLVD\nKANSAS CITY 64132\n(39.007...
# 96219                                                NaN
#
# [96220 rows x 23 columns]         Report_No Reported_Date Reported_Time   From_Date From_Time  \
# 0      KC21055624     8/21/2021         19:45   8/21/2021     19:45
# 1      KC21012401     2/24/2021         11:35   2/24/2021     11:35
# 2      KC21017210     3/17/2021         15:46   3/17/2021     15:35
# 3      KC21005420     1/25/2021         11:18   1/25/2021     11:00
# 4      KC21010791     2/17/2021         11:41   2/11/2021     20:30
# ...           ...           ...           ...         ...       ...
# 92122  KC21076282     11/9/2021         15:00   11/9/2021      9:00
# 92123  KC21076332     11/9/2021         18:16   11/9/2021     18:16
# 92124  KC21075091     11/4/2021         17:21   11/4/2021     17:00
# 92125  KC21079213    11/21/2021         12:33  11/21/2021     11:30
# 92126  KC21077784    11/16/2021          3:11  11/16/2021      3:11
#
#           To_Date To_Time                               Offense IBRS  \
# 0             NaN     NaN                                Murder  09A
# 1             NaN     NaN      Stealing from Building/Residence  23D
# 2             NaN     NaN                  Assault (Aggravated)  13A
# 3             NaN     NaN                 Recovered Stolen Auto  NaN
# 4       2/11/2021   20:45                           Stolen Auto  240
# ...           ...     ...                                   ...  ...
# 92122         NaN     NaN  Stealing from Auto (Theft from Auto)  23G
# 92123         NaN     NaN                  Assault (Aggravated)  13A
# 92124   11/4/2021   17:00                   Stealing – Shoplift  23C
# 92125  11/21/2021   12:00                      Stealing – Other  280
# 92126         NaN     NaN                  Assault (Aggravated)  13A
#
#                                   Description  ... Rep_Dist Area DVFlag  \
# 0                                      Murder  ...   PJ2878  EPD  False
# 1                         Theft From Building  ...   PJ6174  MPD  False
# 2                          Aggravated Assault  ...      NaN  SCP  False
# 3                                         NaN  ...      NaN  CPD  False
# 4                         Motor Vehicle Theft  ...   PJ4215  MPD  False
# ...                                       ...  ...      ...  ...    ...
# 92122  Theft of Vehicle Parts and Accessories  ...   PJ1751  CPD  False
# 92123                      Aggravated Assault  ...   PJ1860  CPD  False
# 92124                             Shoplifting  ...   PJ3601  EPD  False
# 92125                Stolen Property Offenses  ...   PJ3103  CPD  False
# 92126                      Aggravated Assault  ...   PJ3424  CPD  False
#
#        Involvement Race  Sex   Age Firearm Used Flag  \
# 0              VIC    B    M   NaN              True
# 1              SUS    B    M   NaN             False
# 2          ARR CHA    B    M  33.0              True
# 3              SUS    W    F  20.0             False
# 4              SUS    W    M   NaN             False
# ...            ...  ...  ...   ...               ...
# 92122          VIC    W    F  46.0             False
# 92123  ARR CHA SUS    B    M  38.0             False
# 92124          VIC  NaN  NaN   NaN             False
# 92125          VIC    W    F  96.0             False
# 92126          VIC    B    F  32.0             False
#
#                            Location Age_Range
# 0                               NaN       NaN
# 1                               NaN       NaN
# 2                               NaN     25-34
# 3                               NaN     18-24
# 4                               NaN       NaN
# ...                             ...       ...
# 92122   POINT (-94.56125 39.086417)     45-54
# 92123   POINT (-94.58278 39.084205)     35-44
# 92124                           NaN       NaN
# 92125  POINT (-94.603686 39.057644)       75+
# 92126  POINT (-94.559785 39.048451)     25-34
#
# [92127 rows x 24 columns]

# %% [markdown]
# # Dropping fields that were present in few datasets

# %% [markdown]
# From the exploration stage, it was noticed that some datasets had extra fields. Two fields were identified: ‘invl_key’ and ‘Age_Range’
# The 'invl'_no field was only present in 2017 and 2018 datasets, while ‘Age_Range’ field was only present in 2021 dataset. I went ahead to delete these fields from the datasets to make sure all datasets have same number of fields before merging them. The code below shows the dropping of the fiuelds3 and 4 below shows the code for deleting the fields.

# %%
#drop column Invl_no from 2017 and 2018 datasets
groupDF = [df17, df18]
for i in groupDF:
   # i.columns = ['Invl_No']
    i.drop('Invl_No', axis=1, inplace=True)

# %%
print(df17, df18)
# Out:
#         Report_No Reported_Date Reported_Time   From_Date From_Time  \
# 0       170096892    11/14/2017         15:39  11/14/2017     15:06
# 1       170021297    03/25/2017         18:28  03/25/2017     18:26
# 2       170069219    08/07/2017         14:46  08/07/2017     14:40
# 3       170107018    12/23/2017         20:10  12/23/2017     20:10
# 4       170077301    09/04/2017         22:21  08/30/2017     18:00
# ...           ...           ...           ...         ...       ...
# 132134  170065892    07/26/2017         09:09  07/26/2017     09:09
# 132135  170102647    12/06/2017         22:59  12/06/2017     22:59
# 132136  170084282    09/28/2017         12:44  09/27/2017     23:00
# 132137  170094257    11/04/2017         12:06  11/04/2017     12:06
# 132138  170085448    10/02/2017         20:12  10/02/2017     19:30
#
#            To_Date To_Time  Offense IBRS           Description  ...  Zip Code  \
# 0              NaN     NaN      630  23C  Stealing Shoplifting  ...     64105
# 1              NaN     NaN     1850  35B  Possession of Drug E  ...     64129
# 2              NaN     NaN     2655  90J           Trespassing  ...     64151
# 3              NaN     NaN      802  13B  Non Agg Assault Dome  ...     64134
# 4       09/04/2017   22:21      302  120         Armed Robbery  ...     64130
# ...            ...     ...      ...  ...                   ...  ...       ...
# 132134         NaN     NaN      401  13A  Aggravated Assault (  ...     64130
# 132135  12/06/2017   22:59      801  13B  Non Aggravated Assau  ...     64111
# 132136  09/28/2017   09:00      702  240            Auto Theft  ...     64132
# 132137         NaN     NaN      630  23C  Stealing Shoplifting  ...     64155
# 132138         NaN     NaN      302  120         Armed Robbery  ...     64109
#
#        Rep_Dist Area  DVFlag Involvement Race  Sex   Age Firearm Used Flag  \
# 0           NaN  NaN       U         VIC  NaN  NaN   NaN                 N
# 1        PJ2738  EPD       U         VIC  NaN  NaN   NaN                 N
# 2        PP0365  NPD       U         VIC  NaN  NaN   NaN                 N
# 3        PJ7135  SPD       Y         VIC    B    F  18.0                 N
# 4        PJ3077  EPD       U         SUS    B    M  30.0                 N
# ...         ...  ...     ...         ...  ...  ...   ...               ...
# 132134   PJ4382  MPD       U         SUS    U    U   NaN                 Y
# 132135   PJ3485  CPD       U         VIC    W    F  27.0                 N
# 132136   PJ5117  MPD       U         VIC    B    F  22.0                 N
# 132137   PC0323  NPD       U         VIC  NaN  NaN   NaN                 N
# 132138   PJ2479  CPD       N         SUS    B    M   NaN                 Y
#
#                                                  Location
# 0                            200 W 6TH\nKANSAS CITY 64105
# 1                         8900 E US\nHW KANSAS CITY 64129
# 2                     7100 NW BARRY RD\nKANSAS CITY 64151
# 3                        7000 E 113\nTE KANSAS CITY 64134
# 4                  39 ST and NORTON AV\nKANSAS CITY 64130
# ...                                                   ...
# 132134  5300 JACKSON AV\nKANSAS CITY 64130\n(39.029484...
# 132135  4400 WORNALL RD\nKANSAS CITY 64111\n(39.046134...
# 132136  6600 WALROND AV\nKANSAS CITY 64132\n(39.007549...
# 132137  8500 N MADISON AV\nKANSAS CITY 64155\n(39.2483...
# 132138  31 ST and OLIVE ST\nKANSAS CITY 64109\n(39.069...
#
# [132139 rows x 23 columns]         Report_No Reported_Date Reported_Time   From_Date From_Time  \
# 0       180009419    02/07/2018         16:35  02/07/2018     11:00
# 1       180035722    05/20/2018         03:32  05/20/2018     03:32
# 2       180037437    05/19/2018         00:21  05/19/2018       NaN
# 3       180039506    05/26/2018         01:00  05/26/2018     01:00
# 4       180036600    05/16/2018         09:13  05/16/2018     01:00
# ...           ...           ...           ...         ...       ...
# 128933  180098606    12/23/2018         21:45  12/23/2018     21:45
# 128934  180099275    12/27/2018         10:52  12/27/2018     10:52
# 128935  180099745    12/29/2018         09:45  12/24/2018     18:00
# 128936  180098929    12/25/2018         21:33  12/25/2018     21:33
# 128937  180098906    12/25/2018         17:39  12/25/2018     17:00
#
#            To_Date To_Time  Offense IBRS           Description  ... Zip Code  \
# 0       02/07/2018   15:30      640  23F    Stealing From Auto  ...    64127
# 1              NaN     NaN     1352  280  Stolen Property OFFE  ...    64130
# 2              NaN     NaN     2100  90D  Driving Under Influe  ...    64128
# 3              NaN     NaN     2655  90J           Trespassing  ...    64106
# 4       05/16/2018   09:13      702  240            Auto Theft  ...    64105
# ...            ...     ...      ...  ...                   ...  ...      ...
# 128933         NaN     NaN      101  09A  HOMICIDE/Non Neglige  ...    99999
# 128934         NaN     NaN      630  23C  Stealing Shoplifting  ...    64114
# 128935  12/29/2018   08:00      501  220  Burglary - Residence  ...    64145
# 128936         NaN     NaN      802  13B  Non Agg Assault Dome  ...    64132
# 128937         NaN     NaN      630  23C  Stealing Shoplifting  ...    64110
#
#        Rep_Dist Area  DVFlag Involvement Race  Sex   Age Firearm Used Flag  \
# 0        PJ1316  CPD       U         VIC  NaN  NaN   NaN                 N
# 1        PJ2803  EPD       U         ARR    B    M   NaN                 N
# 2        PJ2226  EPD       U         ARR    B    F  46.0                 N
# 3        PJ1084  CPD       U         VIC    W    M  31.0                 N
# 4        PJ1077  CPD       U         SUS    U    U   NaN                 N
# ...         ...  ...     ...         ...  ...  ...   ...               ...
# 128933   PJ1904  EPD       U         VIC    B    M   NaN                 Y
# 128934   PJ6174  MPD       U         SUS    B    M   NaN                 N
# 128935   PJ7370  SPD       U         VIC    W    M  72.0                 N
# 128936   PJ5994  MPD       Y         VIC    B    F  33.0                 N
# 128937   PJ3637  CPD       U         SUS    B    M  40.0                 N
#
#                                                  Location
# 0                          E FOREST AV\nKANSAS CITY 64127
# 1            35 ST and SOUTH BENTON AV\nKANSAS CITY 64130
# 2                    2600 VAN\nBRUNT BL KANSAS CITY 64128
# 3       1200 MAIN ST\nKANSAS CITY 64106\n(39.09961, -9...
# 4       1200 JEFFERSON ST\nKANSAS CITY 64105\n(39.1001...
# ...                                                   ...
# 128933            23 ST and TOPPING AV\nKANSAS CITY 99999
# 128934  8600 WARD PK S\nKANSAS CITY 64114\n(38.971462,...
# 128935                      0 E 127\nTE KANSAS CITY 64145
# 128936  8200 WAYNE AV\nKANSAS CITY 64132\n(38.978977, ...
# 128937  4500 TROOST AV\nKANSAS CITY 64110\n(39.044992,...
#
# [128938 rows x 23 columns]

# %%
#drop age_range field from 2021 dataset
df21.drop('Age_Range', inplace=True, axis=1)

# %%
print(df21)
# Out:
#         Report_No Reported_Date Reported_Time   From_Date From_Time  \
# 0      KC21055624     8/21/2021         19:45   8/21/2021     19:45
# 1      KC21012401     2/24/2021         11:35   2/24/2021     11:35
# 2      KC21017210     3/17/2021         15:46   3/17/2021     15:35
# 3      KC21005420     1/25/2021         11:18   1/25/2021     11:00
# 4      KC21010791     2/17/2021         11:41   2/11/2021     20:30
# ...           ...           ...           ...         ...       ...
# 92122  KC21076282     11/9/2021         15:00   11/9/2021      9:00
# 92123  KC21076332     11/9/2021         18:16   11/9/2021     18:16
# 92124  KC21075091     11/4/2021         17:21   11/4/2021     17:00
# 92125  KC21079213    11/21/2021         12:33  11/21/2021     11:30
# 92126  KC21077784    11/16/2021          3:11  11/16/2021      3:11
#
#           To_Date To_Time                               Offense IBRS  \
# 0             NaN     NaN                                Murder  09A
# 1             NaN     NaN      Stealing from Building/Residence  23D
# 2             NaN     NaN                  Assault (Aggravated)  13A
# 3             NaN     NaN                 Recovered Stolen Auto  NaN
# 4       2/11/2021   20:45                           Stolen Auto  240
# ...           ...     ...                                   ...  ...
# 92122         NaN     NaN  Stealing from Auto (Theft from Auto)  23G
# 92123         NaN     NaN                  Assault (Aggravated)  13A
# 92124   11/4/2021   17:00                   Stealing – Shoplift  23C
# 92125  11/21/2021   12:00                      Stealing – Other  280
# 92126         NaN     NaN                  Assault (Aggravated)  13A
#
#                                   Description  ... Zip Code Rep_Dist Area  \
# 0                                      Murder  ...    64128   PJ2878  EPD
# 1                         Theft From Building  ...    64114   PJ6174  MPD
# 2                          Aggravated Assault  ...    64116      NaN  SCP
# 3                                         NaN  ...    64105      NaN  CPD
# 4                         Motor Vehicle Theft  ...    64130   PJ4215  MPD
# ...                                       ...  ...      ...      ...  ...
# 92122  Theft of Vehicle Parts and Accessories  ...    64108   PJ1751  CPD
# 92123                      Aggravated Assault  ...    64108   PJ1860  CPD
# 92124                             Shoplifting  ...    64133   PJ3601  EPD
# 92125                Stolen Property Offenses  ...    64111   PJ3103  CPD
# 92126                      Aggravated Assault  ...      NaN   PJ3424  CPD
#
#       DVFlag  Involvement Race  Sex   Age Firearm Used Flag  \
# 0      False          VIC    B    M   NaN              True
# 1      False          SUS    B    M   NaN             False
# 2      False      ARR CHA    B    M  33.0              True
# 3      False          SUS    W    F  20.0             False
# 4      False          SUS    W    M   NaN             False
# ...      ...          ...  ...  ...   ...               ...
# 92122  False          VIC    W    F  46.0             False
# 92123  False  ARR CHA SUS    B    M  38.0             False
# 92124  False          VIC  NaN  NaN   NaN             False
# 92125  False          VIC    W    F  96.0             False
# 92126  False          VIC    B    F  32.0             False
#
#                            Location
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 92122   POINT (-94.56125 39.086417)
# 92123   POINT (-94.58278 39.084205)
# 92124                           NaN
# 92125  POINT (-94.603686 39.057644)
# 92126  POINT (-94.559785 39.048451)
#
# [92127 rows x 23 columns]

# %% [markdown]
# # Merging the datasets

# %% [markdown]
# After deleting the extra fields and the datasets had similar fields in similar positions, the provided dataset was enriched by merging the 5 datasets as shown below

# %%
frames = [df17, df18, df19, df20, df21]

df = pd.concat(frames)
print(df)
# Out:
#         Report_No Reported_Date Reported_Time   From_Date From_Time  \
# 0       170096892    11/14/2017         15:39  11/14/2017     15:06
# 1       170021297    03/25/2017         18:28  03/25/2017     18:26
# 2       170069219    08/07/2017         14:46  08/07/2017     14:40
# 3       170107018    12/23/2017         20:10  12/23/2017     20:10
# 4       170077301    09/04/2017         22:21  08/30/2017     18:00
# ...           ...           ...           ...         ...       ...
# 92122  KC21076282     11/9/2021         15:00   11/9/2021      9:00
# 92123  KC21076332     11/9/2021         18:16   11/9/2021     18:16
# 92124  KC21075091     11/4/2021         17:21   11/4/2021     17:00
# 92125  KC21079213    11/21/2021         12:33  11/21/2021     11:30
# 92126  KC21077784    11/16/2021          3:11  11/16/2021      3:11
#
#           To_Date To_Time                               Offense IBRS  \
# 0             NaN     NaN                                   630  23C
# 1             NaN     NaN                                  1850  35B
# 2             NaN     NaN                                  2655  90J
# 3             NaN     NaN                                   802  13B
# 4      09/04/2017   22:21                                   302  120
# ...           ...     ...                                   ...  ...
# 92122         NaN     NaN  Stealing from Auto (Theft from Auto)  23G
# 92123         NaN     NaN                  Assault (Aggravated)  13A
# 92124   11/4/2021   17:00                   Stealing – Shoplift  23C
# 92125  11/21/2021   12:00                      Stealing – Other  280
# 92126         NaN     NaN                  Assault (Aggravated)  13A
#
#                                   Description  ... DVFlag  Involvement Race  \
# 0                        Stealing Shoplifting  ...      U          VIC  NaN
# 1                        Possession of Drug E  ...      U          VIC  NaN
# 2                                 Trespassing  ...      U          VIC  NaN
# 3                        Non Agg Assault Dome  ...      Y          VIC    B
# 4                               Armed Robbery  ...      U          SUS    B
# ...                                       ...  ...    ...          ...  ...
# 92122  Theft of Vehicle Parts and Accessories  ...  False          VIC    W
# 92123                      Aggravated Assault  ...  False  ARR CHA SUS    B
# 92124                             Shoplifting  ...  False          VIC  NaN
# 92125                Stolen Property Offenses  ...  False          VIC    W
# 92126                      Aggravated Assault  ...  False          VIC    B
#
#        Sex   Age Firearm Used Flag                                Location  \
# 0      NaN   NaN                 N            200 W 6TH\nKANSAS CITY 64105
# 1      NaN   NaN                 N         8900 E US\nHW KANSAS CITY 64129
# 2      NaN   NaN                 N     7100 NW BARRY RD\nKANSAS CITY 64151
# 3        F  18.0                 N        7000 E 113\nTE KANSAS CITY 64134
# 4        M  30.0                 N  39 ST and NORTON AV\nKANSAS CITY 64130
# ...    ...   ...               ...                                     ...
# 92122    F  46.0             False             POINT (-94.56125 39.086417)
# 92123    M  38.0             False             POINT (-94.58278 39.084205)
# 92124  NaN   NaN             False                                     NaN
# 92125    F  96.0             False            POINT (-94.603686 39.057644)
# 92126    F  32.0             False            POINT (-94.559785 39.048451)
#
#       Reported Time From Time To Time
# 0               NaN       NaN     NaN
# 1               NaN       NaN     NaN
# 2               NaN       NaN     NaN
# 3               NaN       NaN     NaN
# 4               NaN       NaN     NaN
# ...             ...       ...     ...
# 92122           NaN       NaN     NaN
# 92123           NaN       NaN     NaN
# 92124           NaN       NaN     NaN
# 92125           NaN       NaN     NaN
# 92126           NaN       NaN     NaN
#
# [553196 rows x 26 columns]

# %% [markdown]
# # Renaming field names / Merging datasets

# %% [markdown]
# The 2020 dataset had field names that were missing under scores. The code below shows the renaming of the field names, and then redoing the process of maerging

# %%
#rename columns in 2020 dataset
df20.rename(columns = {'To Time':'To_Time', 'From Time':'From_Time', 'Reported Time':'Reported_Time' }, inplace = True)

# %%
#concatenate dataframes while recalculating index

frames = [df17, df18, df19, df20, df21]

df = pd.concat(frames, ignore_index=True)

#create a new csv file

df.to_csv('alldf.csv') 

print(df)
# Out:
#          Report_No Reported_Date Reported_Time   From_Date From_Time  \
# 0        170096892    11/14/2017         15:39  11/14/2017     15:06
# 1        170021297    03/25/2017         18:28  03/25/2017     18:26
# 2        170069219    08/07/2017         14:46  08/07/2017     14:40
# 3        170107018    12/23/2017         20:10  12/23/2017     20:10
# 4        170077301    09/04/2017         22:21  08/30/2017     18:00
# ...            ...           ...           ...         ...       ...
# 553191  KC21076282     11/9/2021         15:00   11/9/2021      9:00
# 553192  KC21076332     11/9/2021         18:16   11/9/2021     18:16
# 553193  KC21075091     11/4/2021         17:21   11/4/2021     17:00
# 553194  KC21079213    11/21/2021         12:33  11/21/2021     11:30
# 553195  KC21077784    11/16/2021          3:11  11/16/2021      3:11
#
#            To_Date To_Time                               Offense IBRS  \
# 0              NaN     NaN                                   630  23C
# 1              NaN     NaN                                  1850  35B
# 2              NaN     NaN                                  2655  90J
# 3              NaN     NaN                                   802  13B
# 4       09/04/2017   22:21                                   302  120
# ...            ...     ...                                   ...  ...
# 553191         NaN     NaN  Stealing from Auto (Theft from Auto)  23G
# 553192         NaN     NaN                  Assault (Aggravated)  13A
# 553193   11/4/2021   17:00                   Stealing – Shoplift  23C
# 553194  11/21/2021   12:00                      Stealing – Other  280
# 553195         NaN     NaN                  Assault (Aggravated)  13A
#
#                                    Description  ... Zip Code Rep_Dist Area  \
# 0                         Stealing Shoplifting  ...    64105      NaN  NaN
# 1                         Possession of Drug E  ...    64129   PJ2738  EPD
# 2                                  Trespassing  ...    64151   PP0365  NPD
# 3                         Non Agg Assault Dome  ...    64134   PJ7135  SPD
# 4                                Armed Robbery  ...    64130   PJ3077  EPD
# ...                                        ...  ...      ...      ...  ...
# 553191  Theft of Vehicle Parts and Accessories  ...    64108   PJ1751  CPD
# 553192                      Aggravated Assault  ...    64108   PJ1860  CPD
# 553193                             Shoplifting  ...    64133   PJ3601  EPD
# 553194                Stolen Property Offenses  ...    64111   PJ3103  CPD
# 553195                      Aggravated Assault  ...      NaN   PJ3424  CPD
#
#        DVFlag  Involvement Race  Sex   Age Firearm Used Flag  \
# 0           U          VIC  NaN  NaN   NaN                 N
# 1           U          VIC  NaN  NaN   NaN                 N
# 2           U          VIC  NaN  NaN   NaN                 N
# 3           Y          VIC    B    F  18.0                 N
# 4           U          SUS    B    M  30.0                 N
# ...       ...          ...  ...  ...   ...               ...
# 553191  False          VIC    W    F  46.0             False
# 553192  False  ARR CHA SUS    B    M  38.0             False
# 553193  False          VIC  NaN  NaN   NaN             False
# 553194  False          VIC    W    F  96.0             False
# 553195  False          VIC    B    F  32.0             False
#
#                                       Location
# 0                 200 W 6TH\nKANSAS CITY 64105
# 1              8900 E US\nHW KANSAS CITY 64129
# 2          7100 NW BARRY RD\nKANSAS CITY 64151
# 3             7000 E 113\nTE KANSAS CITY 64134
# 4       39 ST and NORTON AV\nKANSAS CITY 64130
# ...                                        ...
# 553191             POINT (-94.56125 39.086417)
# 553192             POINT (-94.58278 39.084205)
# 553193                                     NaN
# 553194            POINT (-94.603686 39.057644)
# 553195            POINT (-94.559785 39.048451)
#
# [553196 rows x 23 columns]

# %% [markdown]
# # Filtering

# %% [markdown]
# After enriching, the dataset was filtered to remain with only the data about wire fraud using the code below:

# %%
#create df where description is wire fraud

wirefraud = df[df['Description'] == 'Wire Fraud']

# %%
print(wirefraud)
# Out:
#          Report_No Reported_Date Reported_Time   From_Date From_Time  \
# 985      170057704    06/29/2017         21:20  03/17/2017     06:00
# 1346     170026998    04/15/2017         13:30  03/03/2017     15:35
# 2092     170053661    06/15/2017         18:13  06/15/2017     07:45
# 2613     170062844    07/18/2017         10:23  07/13/2017     08:00
# 2951     170095971    11/10/2017         19:49  11/10/2017     12:05
# ...            ...           ...           ...         ...       ...
# 552107  KC21075359     11/5/2021         17:54    5/2/2021      0:01
# 552400  KC21070162    10/16/2021         14:11  10/14/2021      9:30
# 552552  KC21077942    11/16/2021         18:50  10/30/2021     16:27
# 552689  KC21083928    12/10/2021         13:40   12/9/2021     11:00
# 553141  KC21079616    11/23/2021          8:43  11/10/2021     13:00
#
#            To_Date To_Time                                            Offense  \
# 985     06/29/2017     NaN                                               1188
# 1346           NaN     NaN                                               1188
# 2092           NaN     NaN                                               1188
# 2613           NaN     NaN                                               1188
# 2951    11/10/2017   17:21                                               1188
# ...            ...     ...                                                ...
# 552107         NaN     NaN  Fraud / Stealing Through Deceit (Scam/Confiden...
# 552400  10/15/2021   16:00  Fraud / Stealing Through Deceit (Scam/Confiden...
# 552552         NaN     NaN                  Fraudulent Use of a Credit Device
# 552689   12/9/2021   17:00  Fraud / Stealing Through Deceit (Scam/Confiden...
# 553141  11/22/2021    8:30  Fraud / Stealing Through Deceit (Scam/Confiden...
#
#        IBRS Description  ... Zip Code Rep_Dist Area DVFlag Involvement Race  \
# 985     26E  Wire Fraud  ...    64134   PJ6607  SPD      U         SUS    U
# 1346    26E  Wire Fraud  ...    64134   PJ5958  MPD      U         SUS    U
# 2092    26E  Wire Fraud  ...    64127   PJ1049  EPD      U         VIC    B
# 2613    26E  Wire Fraud  ...    64155   PC0298  SCP      N         SUS    U
# 2951    26E  Wire Fraud  ...    64153   PP0334  NPD      N         SUS    U
# ...     ...         ...  ...      ...      ...  ...    ...         ...  ...
# 552107  26E  Wire Fraud  ...    64155      NaN  SCP  False     CMP VIC    W
# 552400  26E  Wire Fraud  ...    64133   PJ5648  MPD  False         SUS    U
# 552552  26E  Wire Fraud  ...    64152   PP0549  NPD  False         VIC    W
# 552689  26E  Wire Fraud  ...    64111   PJ3137  CPD  False         VIC  NaN
# 553141  26E  Wire Fraud  ...    64153   PP0241  NPD  False         VIC  NaN
#
#         Sex   Age Firearm Used Flag  \
# 985       U   NaN                 N
# 1346      U   NaN                 N
# 2092      F  20.0                 N
# 2613      U   NaN                 N
# 2951      U   NaN                 N
# ...     ...   ...               ...
# 552107    M  42.0             False
# 552400    M   NaN             False
# 552552    F  44.0             False
# 552689  NaN   NaN             False
# 553141  NaN   NaN             False
#
#                                                  Location
# 985     5800 E 97 ST\nKANSAS CITY 64134\n(38.948758, -...
# 1346    8100 BELLEVIEW AV\nKANSAS CITY 64134\n(38.9815...
# 2092    1100 BELLEFONTAINE AV\nKANSAS CITY 64127\n(39....
# 2613    1000 NE 87\nTE KANSAS CITY 64155\n(39.252781, ...
# 2951    8400 N CARSON AV\nKANSAS CITY 64153\n(39.24713...
# ...                                                   ...
# 552107                                                NaN
# 552400                        POINT (-94.496732 38.99202)
# 552552                       POINT (-94.664236 39.225043)
# 552689                       POINT (-94.586109 39.056586)
# 553141                       POINT (-94.669949 39.277334)
#
# [1610 rows x 23 columns]

# %%
#saving a csv file
wirefraud.to_csv('wirefraud.csv')

# %%
#Reading csv files
dff = pd.read_csv("wirefraud.csv")

dff.describe()
# Out:
#           Unnamed: 0      Zip Code          Age
# count    1610.000000   1560.000000  1021.000000
# mean   308314.134783  64156.532051    44.375122
# std    170071.144743   1496.673243    18.091091
# min       985.000000  33803.000000    18.000000
# 25%    145295.500000  64117.000000    28.000000
# 50%    324448.500000  64130.000000    42.000000
# 75%    462668.500000  64145.000000    59.000000
# max    553141.000000  99999.000000    92.000000

# %% [markdown]
# # Restructuring Wirefraud Data frame

# %% [markdown]
# After creating the new data frame which has information about wirefraud only, it was time to restructure the data frame further by renaming the fields to have the same underscore style between words as shown below.

# %%
#rename columns in wirefraud dataset
dff.rename(columns = {'Zip Code':'Zip_Code', 'Firearm Used Flag':'Firearm_Used_Flag'}, inplace = True)

# %%
#drop age_range field from 2021 dataset
dff.drop(['To_Date','To_Time'], inplace=True, axis=1)

# %%
print(dff)
# Out:
#       Unnamed: 0   Report_No Reported_Date Reported_Time   From_Date  \
# 0            985   170057704    06/29/2017         21:20  03/17/2017
# 1           1346   170026998    04/15/2017         13:30  03/03/2017
# 2           2092   170053661    06/15/2017         18:13  06/15/2017
# 3           2613   170062844    07/18/2017         10:23  07/13/2017
# 4           2951   170095971    11/10/2017         19:49  11/10/2017
# ...          ...         ...           ...           ...         ...
# 1605      552107  KC21075359     11/5/2021         17:54    5/2/2021
# 1606      552400  KC21070162    10/16/2021         14:11  10/14/2021
# 1607      552552  KC21077942    11/16/2021         18:50  10/30/2021
# 1608      552689  KC21083928    12/10/2021         13:40   12/9/2021
# 1609      553141  KC21079616    11/23/2021          8:43  11/10/2021
#
#      From_Time                                            Offense IBRS  \
# 0        06:00                                               1188  26E
# 1        15:35                                               1188  26E
# 2        07:45                                               1188  26E
# 3        08:00                                               1188  26E
# 4        12:05                                               1188  26E
# ...        ...                                                ...  ...
# 1605      0:01  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
# 1606      9:30  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
# 1607     16:27                  Fraudulent Use of a Credit Device  26E
# 1608     11:00  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
# 1609     13:00  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
#
#      Description   Beat  ... Zip_Code Rep_Dist  Area DVFlag Involvement Race  \
# 0     Wire Fraud  542.0  ...  64134.0   PJ6607   SPD      U         SUS    U
# 1     Wire Fraud  233.0  ...  64134.0   PJ5958   MPD      U         SUS    U
# 2     Wire Fraud  321.0  ...  64127.0   PJ1049   EPD      U         VIC    B
# 3     Wire Fraud  642.0  ...  64155.0   PC0298   SCP      N         SUS    U
# 4     Wire Fraud  421.0  ...  64153.0   PP0334   NPD      N         SUS    U
# ...          ...    ...  ...      ...      ...   ...    ...         ...  ...
# 1605  Wire Fraud    642  ...  64155.0      NaN   SCP  False     CMP VIC    W
# 1606  Wire Fraud    243  ...  64133.0   PJ5648   MPD  False         SUS    U
# 1607  Wire Fraud    421  ...  64152.0   PP0549   NPD  False         VIC    W
# 1608  Wire Fraud    133  ...  64111.0   PJ3137   CPD  False         VIC  NaN
# 1609  Wire Fraud    425  ...  64153.0   PP0241   NPD  False         VIC  NaN
#
#       Sex   Age Firearm_Used_Flag  \
# 0       U   NaN                 N
# 1       U   NaN                 N
# 2       F  20.0                 N
# 3       U   NaN                 N
# 4       U   NaN                 N
# ...   ...   ...               ...
# 1605    M  42.0             False
# 1606    M   NaN             False
# 1607    F  44.0             False
# 1608  NaN   NaN             False
# 1609  NaN   NaN             False
#
#                                                Location
# 0     5800 E 97 ST\nKANSAS CITY 64134\n(38.948758, -...
# 1     8100 BELLEVIEW AV\nKANSAS CITY 64134\n(38.9815...
# 2     1100 BELLEFONTAINE AV\nKANSAS CITY 64127\n(39....
# 3     1000 NE 87\nTE KANSAS CITY 64155\n(39.252781, ...
# 4     8400 N CARSON AV\nKANSAS CITY 64153\n(39.24713...
# ...                                                 ...
# 1605                                                NaN
# 1606                        POINT (-94.496732 38.99202)
# 1607                       POINT (-94.664236 39.225043)
# 1608                       POINT (-94.586109 39.056586)
# 1609                       POINT (-94.669949 39.277334)
#
# [1610 rows x 22 columns]

# %% [markdown]
# # Handling Missing Values

# %% [markdown]
# The last step in cleaning was to replace all null values with the word ‘Not provided’ to show that the values were not yet present in the data frame. I chose this option because the null values are in several fields and not very significant to the objective of the study question.

# %%
#replace all missing values with 'Not provided'
dff.fillna(value='Not Provided', inplace=True)

# %%
print(dff)
# Out:
#       Unnamed: 0   Report_No Reported_Date Reported_Time   From_Date  \
# 0            985   170057704    06/29/2017         21:20  03/17/2017
# 1           1346   170026998    04/15/2017         13:30  03/03/2017
# 2           2092   170053661    06/15/2017         18:13  06/15/2017
# 3           2613   170062844    07/18/2017         10:23  07/13/2017
# 4           2951   170095971    11/10/2017         19:49  11/10/2017
# ...          ...         ...           ...           ...         ...
# 1605      552107  KC21075359     11/5/2021         17:54    5/2/2021
# 1606      552400  KC21070162    10/16/2021         14:11  10/14/2021
# 1607      552552  KC21077942    11/16/2021         18:50  10/30/2021
# 1608      552689  KC21083928    12/10/2021         13:40   12/9/2021
# 1609      553141  KC21079616    11/23/2021          8:43  11/10/2021
#
#      From_Time                                            Offense IBRS  \
# 0        06:00                                               1188  26E
# 1        15:35                                               1188  26E
# 2        07:45                                               1188  26E
# 3        08:00                                               1188  26E
# 4        12:05                                               1188  26E
# ...        ...                                                ...  ...
# 1605      0:01  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
# 1606      9:30  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
# 1607     16:27                  Fraudulent Use of a Credit Device  26E
# 1608     11:00  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
# 1609     13:00  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
#
#      Description   Beat  ... Zip_Code      Rep_Dist Area DVFlag Involvement  \
# 0     Wire Fraud  542.0  ...  64134.0        PJ6607  SPD      U         SUS
# 1     Wire Fraud  233.0  ...  64134.0        PJ5958  MPD      U         SUS
# 2     Wire Fraud  321.0  ...  64127.0        PJ1049  EPD      U         VIC
# 3     Wire Fraud  642.0  ...  64155.0        PC0298  SCP      N         SUS
# 4     Wire Fraud  421.0  ...  64153.0        PP0334  NPD      N         SUS
# ...          ...    ...  ...      ...           ...  ...    ...         ...
# 1605  Wire Fraud    642  ...  64155.0  Not Provided  SCP  False     CMP VIC
# 1606  Wire Fraud    243  ...  64133.0        PJ5648  MPD  False         SUS
# 1607  Wire Fraud    421  ...  64152.0        PP0549  NPD  False         VIC
# 1608  Wire Fraud    133  ...  64111.0        PJ3137  CPD  False         VIC
# 1609  Wire Fraud    425  ...  64153.0        PP0241  NPD  False         VIC
#
#               Race           Sex           Age Firearm_Used_Flag  \
# 0                U             U  Not Provided                 N
# 1                U             U  Not Provided                 N
# 2                B             F          20.0                 N
# 3                U             U  Not Provided                 N
# 4                U             U  Not Provided                 N
# ...            ...           ...           ...               ...
# 1605             W             M          42.0             False
# 1606             U             M  Not Provided             False
# 1607             W             F          44.0             False
# 1608  Not Provided  Not Provided  Not Provided             False
# 1609  Not Provided  Not Provided  Not Provided             False
#
#                                                Location
# 0     5800 E 97 ST\nKANSAS CITY 64134\n(38.948758, -...
# 1     8100 BELLEVIEW AV\nKANSAS CITY 64134\n(38.9815...
# 2     1100 BELLEFONTAINE AV\nKANSAS CITY 64127\n(39....
# 3     1000 NE 87\nTE KANSAS CITY 64155\n(39.252781, ...
# 4     8400 N CARSON AV\nKANSAS CITY 64153\n(39.24713...
# ...                                                 ...
# 1605                                       Not Provided
# 1606                        POINT (-94.496732 38.99202)
# 1607                       POINT (-94.664236 39.225043)
# 1608                       POINT (-94.586109 39.056586)
# 1609                       POINT (-94.669949 39.277334)
#
# [1610 rows x 22 columns]

# %%
dff['Firearm_Used_Flag'] = dff['Firearm_Used_Flag'].replace('N','FALSE')
print(dff)
# Out:
#       Unnamed: 0   Report_No Reported_Date Reported_Time   From_Date  \
# 0            985   170057704    06/29/2017         21:20  03/17/2017
# 1           1346   170026998    04/15/2017         13:30  03/03/2017
# 2           2092   170053661    06/15/2017         18:13  06/15/2017
# 3           2613   170062844    07/18/2017         10:23  07/13/2017
# 4           2951   170095971    11/10/2017         19:49  11/10/2017
# ...          ...         ...           ...           ...         ...
# 1605      552107  KC21075359     11/5/2021         17:54    5/2/2021
# 1606      552400  KC21070162    10/16/2021         14:11  10/14/2021
# 1607      552552  KC21077942    11/16/2021         18:50  10/30/2021
# 1608      552689  KC21083928    12/10/2021         13:40   12/9/2021
# 1609      553141  KC21079616    11/23/2021          8:43  11/10/2021
#
#      From_Time                                            Offense IBRS  \
# 0        06:00                                               1188  26E
# 1        15:35                                               1188  26E
# 2        07:45                                               1188  26E
# 3        08:00                                               1188  26E
# 4        12:05                                               1188  26E
# ...        ...                                                ...  ...
# 1605      0:01  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
# 1606      9:30  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
# 1607     16:27                  Fraudulent Use of a Credit Device  26E
# 1608     11:00  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
# 1609     13:00  Fraud / Stealing Through Deceit (Scam/Confiden...  26E
#
#      Description   Beat  ... Zip_Code      Rep_Dist Area DVFlag Involvement  \
# 0     Wire Fraud  542.0  ...  64134.0        PJ6607  SPD      U         SUS
# 1     Wire Fraud  233.0  ...  64134.0        PJ5958  MPD      U         SUS
# 2     Wire Fraud  321.0  ...  64127.0        PJ1049  EPD      U         VIC
# 3     Wire Fraud  642.0  ...  64155.0        PC0298  SCP      N         SUS
# 4     Wire Fraud  421.0  ...  64153.0        PP0334  NPD      N         SUS
# ...          ...    ...  ...      ...           ...  ...    ...         ...
# 1605  Wire Fraud    642  ...  64155.0  Not Provided  SCP  False     CMP VIC
# 1606  Wire Fraud    243  ...  64133.0        PJ5648  MPD  False         SUS
# 1607  Wire Fraud    421  ...  64152.0        PP0549  NPD  False         VIC
# 1608  Wire Fraud    133  ...  64111.0        PJ3137  CPD  False         VIC
# 1609  Wire Fraud    425  ...  64153.0        PP0241  NPD  False         VIC
#
#               Race           Sex           Age Firearm_Used_Flag  \
# 0                U             U  Not Provided             FALSE
# 1                U             U  Not Provided             FALSE
# 2                B             F          20.0             FALSE
# 3                U             U  Not Provided             FALSE
# 4                U             U  Not Provided             FALSE
# ...            ...           ...           ...               ...
# 1605             W             M          42.0             False
# 1606             U             M  Not Provided             False
# 1607             W             F          44.0             False
# 1608  Not Provided  Not Provided  Not Provided             False
# 1609  Not Provided  Not Provided  Not Provided             False
#
#                                                Location
# 0     5800 E 97 ST\nKANSAS CITY 64134\n(38.948758, -...
# 1     8100 BELLEVIEW AV\nKANSAS CITY 64134\n(38.9815...
# 2     1100 BELLEFONTAINE AV\nKANSAS CITY 64127\n(39....
# 3     1000 NE 87\nTE KANSAS CITY 64155\n(39.252781, ...
# 4     8400 N CARSON AV\nKANSAS CITY 64153\n(39.24713...
# ...                                                 ...
# 1605                                       Not Provided
# 1606                        POINT (-94.496732 38.99202)
# 1607                       POINT (-94.664236 39.225043)
# 1608                       POINT (-94.586109 39.056586)
# 1609                       POINT (-94.669949 39.277334)
#
# [1610 rows x 22 columns]

# %% [markdown]
# # Saving the clean CSV file

# %% [markdown]
# The final step was to publish the dataset in a CSV format that can be imported in Python or Tableau for further analysis.

# %%
dff.to_csv('wirefraudfinal.csv')
